# %%
# from selenium import webdriver

# # Using Chrome to access web
# driver = webdriver.Chrome()

# #get url
# driver.get('https://www.idx.co.id/perusahaan-tercatat/laporan-keuangan-dan-tahunan/')
# #selecting option from period
# driver.find_element_by_xpath ("//select[@id ='periodList']/option[text()='Triwulan 1']").click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import requests

import re
import pandas as pd
import os
import time

url = "https://www.idx.co.id/perusahaan-tercatat/laporan-keuangan-dan-tahunan/"
#create a new chrome session
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get(url)

# selecting option from period
driver.find_element_by_xpath ("//select[@id ='periodList']/option[text()='Triwulan 2']").click()
#click cari
driver.find_element_by_xpath ("//button[@id = 'searchButton']").click()
pageCounter = 0

time.sleep(3)



#BeautifulSoup grabs all financial report links
while pageCounter < 2:
    soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
    for div in soup_level1.findAll('div', attrs ={'class':'financial-report-download ng-scope'}):
        links = div.findAll('a', attrs = {'class':'ng-binding'}, href=re.compile("FinancialStatement"))
        for a in links:
#             driver.find_element_by_xpath("//div[@ng-repeat = 'attachments in res.Attachments']").click()
            files = [url + a['href']]
            for file in files:
                file_name = file.split('/')[-1]    
  
                print ("Downloading file:%s"%file_name)
          
                # create response object 
                r = requests.get(file, stream = True) 
          
                # download started 
                with open(file_name, 'wb') as f: 
                    for chunk in r.iter_content(chunk_size=10000): 
                        if chunk: 
                            f.write(chunk)
                            
                print ("%s downloaded!\n"%file_name)
                
    driver.find_element_by_xpath("//a[@href=''][text()='›']").click()
    
    time.sleep(3)
    pageCounter=pageCounter+1
# Out:
# Downloading file:FinancialStatement-2019-II-AALI.pdf
# FinancialStatement-2019-II-AALI.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AALI.xlsx
# FinancialStatement-2019-II-AALI.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ABDA.pdf
# FinancialStatement-2019-II-ABDA.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ABDA.xlsx
# FinancialStatement-2019-II-ABDA.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ABMM.xlsx
# FinancialStatement-2019-II-ABMM.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ABMM.pdf
# FinancialStatement-2019-II-ABMM.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ACES.pdf
# FinancialStatement-2019-II-ACES.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ACES.xlsx
# FinancialStatement-2019-II-ACES.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ACST.pdf
# FinancialStatement-2019-II-ACST.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ACST.xlsx
# FinancialStatement-2019-II-ACST.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADES.xlsx
# FinancialStatement-2019-II-ADES.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADES.pdf
# FinancialStatement-2019-II-ADES.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADHI.xlsx
# FinancialStatement-2019-II-ADHI.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADHI.pdf
# FinancialStatement-2019-II-ADHI.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADMF.xlsx
# FinancialStatement-2019-II-ADMF.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADMF.pdf
# FinancialStatement-2019-II-ADMF.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADMG.xlsx
# FinancialStatement-2019-II-ADMG.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADMG.pdf
# FinancialStatement-2019-II-ADMG.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADRO.xlsx
# FinancialStatement-2019-II-ADRO.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ADRO.pdf
# FinancialStatement-2019-II-ADRO.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGII.xlsx
# FinancialStatement-2019-II-AGII.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGII.pdf
# FinancialStatement-2019-II-AGII.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGRO.pdf
# FinancialStatement-2019-II-AGRO.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGRO.xlsx
# FinancialStatement-2019-II-AGRO.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGRS.pdf
# FinancialStatement-2019-II-AGRS.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AGRS.xlsx
# FinancialStatement-2019-II-AGRS.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AHAP.pdf
# FinancialStatement-2019-II-AHAP.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AHAP.xlsx
# FinancialStatement-2019-II-AHAP.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AIMS.pdf
# FinancialStatement-2019-II-AIMS.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AKPI.pdf
# FinancialStatement-2019-II-AKPI.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AKPI.xlsx
# FinancialStatement-2019-II-AKPI.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AKSI.xlsx
# FinancialStatement-2019-II-AKSI.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-AKSI.pdf
# FinancialStatement-2019-II-AKSI.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ALDO.pdf
# FinancialStatement-2019-II-ALDO.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ALKA.pdf
# FinancialStatement-2019-II-ALKA.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-ALKA.xlsx
# FinancialStatement-2019-II-ALKA.xlsx downloaded!

# %%
# !pip install urllib
# Out:
# Collecting urllib
#   ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import requests

import re
import pandas as pd
import os
import time

url = "https://www.idx.co.id/perusahaan-tercatat/laporan-keuangan-dan-tahunan/"
#create a new chrome session
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get(url)

# selecting option from period
driver.find_element_by_xpath ("//select[@id ='periodList']/option[text()='Triwulan 2']").click()
#click cari
driver.find_element_by_xpath ("//button[@id = 'searchButton']").click()
pageCounter = 0

time.sleep(3)

# driver.find_element_by_xpath("//div[@ng-repeat = 'attachments in res.Attachments']").click()

driver.find_element_by_xpath("//a[@href=''][text()='›']").click()

# %%
requests.get('https://www.idx.co.id/Portals/0/StaticData/ListedCompanies/Corporate_Actions/New_Info_JSX/Jenis_Informasi/01_Laporan_Keuangan/02_Soft_Copy_Laporan_Keuangan//Laporan%20Keuangan%20Tahun%202019/TW2/AALI/AALI_LK%20TW%20II%202019.pdf')
# Out:
# <Response [200]>

# %%
import requests
res = requests.get('https://www.idx.co.id/Portals/0/StaticData/ListedCompanies/Corporate_Actions/New_Info_JSX/Jenis_Informasi/01_Laporan_Keuangan/02_Soft_Copy_Laporan_Keuangan//Laporan%20Keuangan%20Tahun%202019/TW2/AALI/AALI_LK%20TW%20II%202019.pdf')
res.raise_for_status()
playFile = open('laporancoba.pdf', 'wb')
for chunk in res.iter_content(100000):
    playFile.write(chunk)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import requests

import re
import pandas as pd
import os
import time

url = "https://www.idx.co.id/perusahaan-tercatat/laporan-keuangan-dan-tahunan/"
#create a new chrome session
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get(url)

# selecting option from period
driver.find_element_by_xpath ("//select[@id ='periodList']/option[text()='Triwulan 2']").click()
time.sleep(3)
#click cari
driver.find_element_by_xpath ("//button[@id = 'searchButton']").click()
pageCounter = 0

time.sleep(3)



#BeautifulSoup grabs all financial report links
while pageCounter < 2:
    soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
    for div in soup_level1.findAll('div', attrs ={'class':'financial-report-download ng-scope'}):
        links = div.findAll('a', attrs = {'class':'ng-binding'}, href=re.compile("FinancialStatement"))
        for a in links:
#             driver.find_element_by_xpath("//div[@ng-repeat = 'attachments in res.Attachments']").click()
            files = [url + a['href']]
            for file in files:
                file_name = file.split('/')[-1]    
  
                print ("Downloading file:%s"%file_name)
          
                # create response object 
                r = requests.get(file, stream = True) 
          
                # download started 
                with open(file_name, 'wb') as f: 
                    f.write(r.content)
                    time.sleep(20)
                            
                print ("%s downloaded!\n"%file_name)
                
    driver.find_element_by_xpath("//a[@href=''][text()='›']").click()
    
    time.sleep(3)
    pageCounter=pageCounter+1
# Out:
# Downloading file:FinancialStatement-2019-II-AALI.pdf
# FinancialStatement-2019-II-AALI.pdf downloaded!
#
# Downloading file:FinancialStatement-2019-II-AALI.xlsx
# FinancialStatement-2019-II-AALI.xlsx downloaded!
#
# Downloading file:FinancialStatement-2019-II-ABDA.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-00b1b772b468> in <module>
#      46                 with open(file_name, 'wb') as f:
#      47                     f.write(r.content)
# ---> 48                     time.sleep(20)
#      49
#      50                 print ("%s downloaded!\n"%file_name)
#
# KeyboardInterrupt:
